# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import sys
import time
import zipfile
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.models import Sequential
from sklearn.cluster import KMeans
from keras.layers import Dense, Conv2D, MaxPool2D, Activation, Flatten, Dropout
from random import randint

import cv2
from sklearn.feature_extraction import image
from sklearn.cluster import spectral_clustering
from sklearn.utils.testing import SkipTest
from sklearn.utils.fixes import sp_version

# %%
directory = '/content/gdrive/My Drive/Colab Notebooks/whale_data/'

df_csv = pd.read_csv(directory + 'train.csv') 

zf = zipfile.ZipFile(directory + 'train.zip', 'r')
images_name = [i for i in zf.namelist() if '__MACOSX/' not in i]
images_name.remove('train/')

print(images_name)
print('\n\ntotal number of images : ' + str(len(images_name)))
# Out:
# ['train/51e7efb28.jpg', 'train/74b09432a.jpg', 'train/a3daa1598.jpg', 'train/3f254878b.jpg', 'train/ad94c9235.jpg', 'train/ba57b8f76.jpg', 'train/dd023673d.jpg', 'train/f414e0cb5.jpg', 'train/89cb3c449.jpg', 'train/924c7c768.jpg', 'train/1e73ca94a.jpg', 'train/1938eedc2.jpg', 'train/bf8ef6dc6.jpg', 'train/4be61d178.jpg', 'train/10fd71c61.jpg', 'train/85a874d1f.jpg', 'train/5dddf0acf.jpg', 'train/048bbca71.jpg', 'train/f45061aff.jpg', 'train/092a3bfa7.jpg', 'train/723e7afb3.jpg', 'train/150c178bf.jpg', 'train/3183ca765.jpg', 'train/8e9da22bd.jpg', 'train/bb3dc811a.jpg', 'train/e074e6fa5.jpg', 'train/7a19cbd2a.jpg', 'train/9eb48770a.jpg', 'train/461bf48f4.jpg', 'train/dd1d43a26.jpg', 'train/5f2fe570c.jpg', 'train/effd02068.jpg', 'train/f12a8b70c.jpg', 'train/d4f882ce4.jpg', 'train/da708a620.jpg', 'train/35d0c766b.jpg', 'train/d04130668.jpg', 'train/dfe4efca4.jpg', 'train/d140375b0.jpg', 'train/3b7e23376.jpg', 'train/db59c1aba.jpg', 'train/d59697e87.jpg', 'train/58e4d84b4.jpg', 'train/7
# ...

# %%
images = []

# preventing from crash
chunk_size = 20

j = 0

t = time.time()

for i in range(int(j / chunk_size * len(images_name)), int((j + 1) / chunk_size * len(images_name)) ):
        images.append(plt.imread(zf.open(images_name[i])))

t1 = time.time() - t
print('execution time for part 1 : ' + str(t1))

# j = 1

# t = time.time()

# for i in range(int(j / chunk_size * len(images_name)), int((j + 1) / chunk_size * len(images_name)) ):
#         images.append(plt.imread(zf.open(images_name[i])))

# t2 = time.time() - t
# print('execution time for part 2 : ' + str(t2))
# print('\n\ntotal execution time : ' + str(t1 + t2))
# Out:
# execution time for part 1 : 6.686022043228149
